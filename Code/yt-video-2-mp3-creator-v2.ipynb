# %%
# These libraries/methods didn't work
# !pip install pytube
# !apt-get install youtube-dl
# !youtube-dl -x --audio-format mp3 https://www.youtube.com/watch?v=8dGLeEHkP9s

# !apt-get install yt-dlp
# !yt-dlp -x --audio-format mp3 https://www.youtube.com/watch?v=8dGLeEHkP9s

# %%
# !pip install yt-dlp --upgrade 

# Install or upgrade yt-dlp
# Out:
# Requirement already satisfied: yt-dlp in c:\python312\lib\site-packages (2024.12.13)
# WARNING: Ignoring invalid distribution ~t-dlp (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~vicorn (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ython-dotenv (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~t-dlp (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~vicorn (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ython-dotenv (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~t-dlp (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~vicorn (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ython-dotenv (C:\Python312\Lib\site-packages)

# %%
# !yt-dlp --version
# Out:
# 2024.12.13

# %%
def get_youtube_title(url):
    """
    Retrieves the title of a YouTube video using yt-dlp.

    Args:
        url: The URL of the YouTube video.

    Returns:
        The title of the video as a string, or None if an error occurs.
    """
    try:
        import subprocess
        import json
        
        # Use subprocess with more detailed error handling
        try:
            result = subprocess.run(
                f"yt-dlp -j '{url}'", 
                shell=True, 
                capture_output=True, 
                text=True, 
                check=True
            )
            video_info = json.loads(result.stdout)
            title = video_info.get('title')
            return title
        except subprocess.CalledProcessError as e:
            print(f"Command failed with error: {e}")
            print(f"STDOUT: {e.stdout}")
            print(f"STDERR: {e.stderr}")
            return None
    except Exception as e:
        print(f"Unexpected error getting video title: {e}")
        return None

def download_youtube_audio(url, output_path=".", output_file="output.mp3"):
    """Downloads the audio of a YouTube video as an MP3 file."""
    import subprocess
    import os
    import glob

    # Ensure output path exists
    output_path = os.path.abspath(output_path)
    os.makedirs(output_path, exist_ok=True)

    try:
        # Construct the download command with additional parameters
        download_command = [
            "yt-dlp",
            "-v",  # Verbose output
            "-x",  # Extract audio
            "--audio-format", "mp3",
            "-o", os.path.join(output_path, "%(title)s.%(ext)s"),
            url
        ]

        # Run the command using subprocess with comprehensive error handling
        print(f"Executing command: {' '.join(download_command)}")
        
        result = subprocess.run(
            download_command, 
            capture_output=True, 
            text=True, 
            check=False  # Don't raise exception on non-zero exit
        )

        # Print detailed output for debugging
        print("STDOUT:", result.stdout)
        print("STDERR:", result.stderr)
        print("Return Code:", result.returncode)

        # Check if the command was successful
        if result.returncode != 0:
            print(f"Download failed with return code {result.returncode}")
            return

        # List all files in the output directory
        print("Files in output directory:")
        for file in os.listdir(output_path):
            print(file)

        # Find MP3 files
        mp3_files = glob.glob(os.path.join(output_path, "*.mp3"))
        
        if not mp3_files:
            print("No MP3 files found after download")
            return

        # Rename the first MP3 file found
        original_file = mp3_files[0]
        new_file_path = os.path.join(output_path, output_file)
        
        os.rename(original_file, new_file_path)
        print(f"Created audio file {new_file_path}")

    except Exception as e:
        import traceback
        print(f"An unexpected error occurred: {e}")
        print(traceback.format_exc())

# %%
import pandas as pd
df = pd.read_csv("list-of-youtube-videos.csv")

# %% [markdown]
# # Enter Sno

# %%
sno=3

# %%
# df

# %%
name = df['title'][df.sno==sno].iloc[0]
youtube_url = df['url'][df.sno==sno].iloc[0]
name, youtube_url
# [download]  87.6% of   89.11MiB at    2.19MiB/s ETA 00:05
# [download]  87.6% of   89.11MiB at    3.54MiB/s ETA 00:03
# [download]  87.6% of   89.11MiB at    1.54MiB/s ETA 00:07
# [download]  87.6% of   89.11MiB at    1.48MiB/s ETA 00:07
# [download]  87.7% of   89.11MiB at    1.87MiB/s ETA 00:05
# [download]  87.8% of   89.11MiB at    2.63MiB/s ETA 00:04
# [download]  88.1% of   89.11MiB at    3.12MiB/s ETA 00:03
# [download]  88.7% of   89.11MiB at    3.57MiB/s ETA 00:02
# [download]  89.8% of   89.11MiB at    4.16MiB/s ETA 00:02
# [download]  92.0% of   89.11MiB at    4.21MiB/s ETA 00:01
# [download]  96.5% of   89.11MiB at    4.14MiB/s ETA 00:00
# [download]  98.5% of   89.11MiB at    4.26MiB/s ETA 00:00
# [download]  98.5% of   89.11MiB at  Unknown B/s ETA Unknown
# [download]  98.5% of   89.11MiB at  Unknown B/s ETA Unknown
# [download]  98.5% of   89.11MiB at  574.34KiB/s ETA 00:02
# [download]  98.5% of   89.11MiB at    1.20MiB/s ETA 00:01
# [download]  98.5% of   89.11MiB at    2.04MiB/s ETA 00:00
# [download]  98.6% of   89.11MiB at    2.18MiB/s ETA 00:00
# [download]  98.6% of   89.11MiB at    2.45MiB/s ETA 00:00
# [download]  98.8% of   89.11MiB at    3.12MiB/s ETA 00:00
# [download]  99.0% of   89.11MiB at    4.05MiB/s ETA 00:00
# [download]  99.6% of   89.11MiB at    5.02MiB/s ETA 00:00
# [download] 100.0% of   89.11MiB at    5.26MiB/s ETA 00:00
# [download] 100% of   89.11MiB in 00:00:19 at 4.47MiB/s
# [ExtractAudio] Destination: d:\github\DAI-Projects\DAI-mp3\Osho-Tao-upnishad\#1 ï¼‚Unlocking Tao Te Ching ï¼š Verse 1 Explainedï¼‚.mp3
# Deleting original file d:\github\DAI-Projects\DAI-mp3\Osho-Tao-upnishad\#1 ï¼‚Unlocking Tao Te Ching ï¼š Verse 1 Explainedï¼‚.webm (pass -k to keep)
#
# STDERR: [debug] Command-line config: ['-v', '-x', '--audio-format', 'mp3', '-o', 'd:\\github\\DAI-Projects\\DAI-mp3\\Osho-Tao-upnishad\\%(title)s.%(ext)s', 'https://www.youtube.com/watch?v=5FHN7Ujy2ks']
# [debug] Encodings: locale cp1252, fs utf-8, pref cp1252, out utf-8 (No VT), error utf-8 (No VT), screen utf-8 (No VT)
# [debug] yt-dlp version stable@2024.12.13 from yt-dlp/yt-dlp [542166962] (pip)
# [debug] Python 3.12.4 (CPython AMD64 64bit) - Windows-11-10.0.22631-SP0 (OpenSSL 3.0.13 30 Jan 2024)
# [debug] exe versions: ffmpeg 2024-08-01-git-bcf08c1171-full_build-www.gyan.dev (setts), ffprobe 2024-08-01-git-bcf08c1171-full_build-www.gyan.dev
# [debug] Optional libraries: certifi-2024.02.02, requests-2.31.0, sqlite3-3.45.3, urllib3-2.2.1, websockets-14.1
# [debug] Proxy map: {}
# [debug] Request Handlers: urllib, websockets
# [debug] Loaded 1837 extractors
# [debug] [youtube] Extracting signature function js_03dbdfab_103
# [debug] Loading youtube-sigfuncs.js_03dbdfab_103 from cache
# [debug] Loading youtube-nsig.03dbdfab from cache
# [debug] [youtube] Decrypted nsig khP4OA1wiFVinVXLl => OTs-V6MGcjUT_Q
# [debug] [youtube] Extracting signature function js_03dbdfab_107
# [debug] Loading youtube-sigfuncs.js_03dbdfab_107 from cache
# [debug] Loading youtube-nsig.03dbdfab from cache
# [debug] [youtube] Decrypted nsig 5VFsLr2ZY-OipWkZH => H996x-GnJnaqeQ
# [debug] Sort order given by extractor: quality, res, fps, hdr:12, source, vcodec, channels, acodec, lang, proto
# [debug] Formats sorted by: hasvid, ie_pref, quality, res, fps, hdr:12(7), source, vcodec, channels, acodec, lang, proto, size, br, asr, vext, aext, hasaud, id
# [debug] Invoking http downloader on "https://rr4---sn-gwpa-5bgs.googlevideo.com/videoplayback?expire=1734893665&ei=AQxoZ6jAN72vjuMP5tyluQw&ip=49.43.168.242&id=o-ALFiQzgT_p_9oLs9ai8W-eyccWR18EJ2Ws7RjQiHiNtC&itag=251&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1734872065%2C&mh=-w&mm=31%2C29&mn=sn-gwpa-5bgs%2Csn-gwpa-qxaz&ms=au%2Crdu&mv=m&mvi=4&pl=24&rms=au%2Cau&initcwndbps=598750&bui=AfMhrI9cU24JVjiOxELte_C1ycv4mKhIw2aCdzBhY6poZGpibK0WZSB3oBeZVJE8h5doGDyOoRgWhjDT&spc=x-caUC70mLMnOGG94NBMQ3e2NZ23bo8epU969PHRTd-_-8PJJshI&vprv=1&svpuc=1&mime=audio%2Fwebm&rqh=1&gir=yes&clen=93440134&dur=5133.621&lmt=1707458784431811&mt=1734871518&fvip=8&keepalive=yes&fexp=51326932%2C51335594%2C51371294&c=IOS&txp=5318224&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cspc%2Cvprv%2Csvpuc%2Cmime%2Crqh%2Cgir%2Cclen%2Cdur%2Clmt&sig=AJfQdSswRgIhANBY3wvms1RJChgcMNB5to2eyOUHoH5xgXSL3W47wFwFAiEA0ezBGIW3IFnxbMZ7exV6KS-ZFH4t0_QKzY11PHtWHHk%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Crms%2Cinitcwndbps&lsig=AGluJ3MwRAIgFo93yqUZE6B6AZLnORV94bFpEg5eUI6O7osBA27rEUICIGr7xptCp7m39lY0k_uaIxHGRNUK2IDiAsMMZ0WhEvkF"
# [debug] File locking is not supported. Proceeding without locking
# [debug] ffmpeg command line: ffprobe -show_streams "file:d:\github\DAI-Projects\DAI-mp3\Osho-Tao-upnishad\#1 ï¼‚Unlocking Tao Te Ching ï¼š Verse 1 Explainedï¼‚.webm"
# [debug] ffmpeg command line: ffmpeg -y -loglevel repeat+info -i "file:d:\github\DAI-Projects\DAI-mp3\Osho-Tao-upnishad\#1 ï¼‚Unlocking Tao Te Ching ï¼š Verse 1 Explainedï¼‚.webm" -vn -acodec libmp3lame -q:a 5.0 -movflags +faststart "file:d:\github\DAI-Projects\DAI-mp3\Osho-Tao-upnishad\#1 ï¼‚Unlocking Tao Te Ching ï¼š Verse 1 Explainedï¼‚.mp3"
#
# Return Code: 0
# Files in output directory:
# #1 ＂Unlocking Tao Te Ching ： Verse 1 Explained＂.mp3
# Tao-002-chapter-02-tao-upnishad-Journey-into-the-Wisdom-of-Lao-Tzu.mp3
# Tao-073-chapter-38-Part2-Degeneration.mp3
# Tao-075-chapter-39-part2-Embrace-Harmony-and-Humility.mp3
# Tao-076-chapter-40-n-41-part1-The-Principle-of-Reversion-n-Qualities.mp3
# Created audio file d:\github\DAI-Projects\DAI-mp3\Osho-Tao-upnishad\Tao-001-chapter-01-Unlocking-Tao.mp3

# %%
# Out:
# 2024.12.13
